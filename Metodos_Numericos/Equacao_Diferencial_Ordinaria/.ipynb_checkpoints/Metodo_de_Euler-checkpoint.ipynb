# %% [markdown]
# # Método de Euler
# Seja um problema de valor inicial da forma:
# $$
# \frac{dy}{dt}(t) = f(t,y), \ {\rm para} \ t \in [a,b],
# $$
# sujeito a uma condição inicial: $y(a) = \alpha \in \mathbb{R}$.
#
# ## Algoritmo
# **Entrada:**
# - função: $f$;
# - extremos do intervalo: $a$ e $b$;
# - condição inicial: $\alpha$
# - número de pontos na malha: $N$;
# - distância entre os pontos: $h = \frac{b-a}{N}$;
# - pontos da malha: $t_i = a + (i-1)h, i = 1,...,N$.
#
# **Método de Euler**
# $$
# w_1 = \alpha
# $$
# $$
# w_{i+1} = w_{i} + h f(t_i,w_i),
# $$
# para $i = 2,3,...,N$

# %% [markdown]
# # Implementação

# %%
# Pacote
using Pkg;
Pkg.add("Plots");
# Out:
#    Updating registry at `C:\Users\Carlos\.julia\registries\General`
#    Updating git-repo `https://github.com/JuliaRegistries/General.git`
# Fetching: [========================================>]  100.0 %[======>                                  ]  14.4 %Fetching: [===============>                         ]  35.3 %>               ]  60.3 %=========================>               ]  60.8 % %
#   Resolving package versions...
#   Installed Reexport ──────────────────── v0.2.0
#   Installed Missings ──────────────────── v0.4.3
#   Installed FFMPEG ────────────────────── v0.3.0
#   Installed FreeType2_jll ─────────────── v2.10.1+2
#   Installed FFMPEG_jll ────────────────── v4.1.0+3
#   Installed FixedPointNumbers ─────────── v0.8.4
#   Installed IterTools ─────────────────── v1.3.0
#   Installed Plots ─────────────────────── v1.5.7
#   Installed TableTraits ───────────────── v1.0.0
#   Installed LibVPX_jll ────────────────── v1.8.1+1
#   Installed libfdk_aac_jll ────────────── v0.1.6+2
#   Installed PlotThemes ────────────────── v2.0.0
#   Installed PlotUtils ─────────────────── v1.0.5
#   Installed OrderedCollections ────────── v1.3.0
#   Installed StatsBase ─────────────────── v0.33.0
#   Installed NaNMath ───────────────────── v0.3.4
#   Installed IteratorInterfaceExtensions ─ v1.0.0
#   Installed StructArrays ──────────────── v0.4.4
#   Installed Measures ──────────────────── v0.3.1
#   Installed x265_jll ──────────────────── v3.0.0+1
#   Installed Contour ───────────────────── v0.5.4
#   Installed StaticArrays ──────────────── v0.12.4
#   Installed LAME_jll ──────────────────── v3.100.0+1
#   Installed Showoff ───────────────────── v0.3.1
#   Installed DataValueInterfaces ───────── v1.0.0
#   Installed FriBidi_jll ───────────────── v1.0.5+3
#   Installed Adapt ─────────────────────── v2.0.2
#   Installed GeometryBasics ────────────── v0.2.15
#   Installed Colors ────────────────────── v0.12.3
#   Installed HTTP ──────────────────────── v0.8.17
#   Installed RecipesBase ───────────────── v1.0.2
#   Installed Requires ──────────────────── v1.0.1
#   Installed SortingAlgorithms ─────────── v0.3.1
#   Installed OpenSSL_jll ───────────────── v1.1.1+4
#   Installed Tables ────────────────────── v1.0.5
#   Installed GeometryTypes ─────────────── v0.8.3
#   Installed IniFile ───────────────────── v0.5.0
#   Installed libass_jll ────────────────── v0.14.0+2
#   Installed x264_jll ──────────────────── v2019.5.25+2
#   Installed Opus_jll ──────────────────── v1.3.1+1
#   Installed RecipesPipeline ───────────── v0.1.11
#   Installed ColorTypes ────────────────── v0.10.7
#   Installed DataStructures ────────────── v0.17.19
#   Installed DataAPI ───────────────────── v1.3.0
#   Installed Zlib_jll ──────────────────── v1.2.11+14
#   Installed libvorbis_jll ─────────────── v1.3.6+4
#   Installed Bzip2_jll ─────────────────── v1.0.6+2
#   Installed Ogg_jll ───────────────────── v1.3.4+0
#   Installed GR ────────────────────────── v0.51.0
#   Installed ColorSchemes ──────────────── v3.9.0
#    Updating `C:\Users\Carlos\.julia\environments\v1.4\Project.toml`
#   [91a5bcdd] + Plots v1.5.7
#    Updating `C:\Users\Carlos\.julia\environments\v1.4\Manifest.toml`
#   [79e6a3ab] + Adapt v2.0.2
#   [6e34b625] + Bzip2_jll v1.0.6+2
#   [35d6a980] + ColorSchemes v3.9.0
#   [3da002f7] + ColorTypes v0.10.7
#   [5ae59095] + Colors v0.12.3
#   [d38c429a] + Contour v0.5.4
#   [9a962f9c] + DataAPI v1.3.0
#   [864edb3b] + DataStructures v0.17.19
#   [e2d170a0] + DataValueInterfaces v1.0.0
#   [c87230d0] + FFMPEG v0.3.0
#   [b22a6f82] + FFMPEG_jll v4.1.0+3
#   [53c48c17] + FixedPointNumbers v0.8.4
#   [d7e528f0] + FreeType2_jll v2.10.1+2
#   [559328eb] + FriBidi_jll v1.0.5+3
#   [28b8d3ca] + GR v0.51.0
#   [5c1252a2] + GeometryBasics v0.2.15
#   [4d00f742] + GeometryTypes v0.8.3
#   [cd3eb016] + HTTP v0.8.17
#   [83e8ac13] + IniFile v0.5.0
#   [c8e1da08] + IterTools v1.3.0
#   [82899510] + IteratorInterfaceExtensions v1.0.0
#   [c1c5ebd0] + LAME_jll v3.100.0+1
#   [dd192d2f] + LibVPX_jll v1.8.1+1
#   [442fdcdd] + Measures v0.3.1
#   [e1d29d7a] + Missings v0.4.3
#   [77ba4419] + NaNMath v0.3.4
#   [e7412a2a] + Ogg_jll v1.3.4+0
#   [458c3c95] + OpenSSL_jll v1.1.1+4
#   [91d4177d] + Opus_jll v1.3.1+1
#   [bac558e1] + OrderedCollections v1.3.0
#   [ccf2f8ad] + PlotThemes v2.0.0
#   [995b91a9] + PlotUtils v1.0.5
#   [91a5bcdd] + Plots v1.5.7
#   [3cdcf5f2] + RecipesBase v1.0.2
#   [01d81517] + RecipesPipeline v0.1.11
#   [189a3867] + Reexport v0.2.0
#   [ae029012] + Requires v1.0.1
#   [992d4aef] + Showoff v0.3.1
#   [a2af1166] + SortingAlgorithms v0.3.1
#   [90137ffa] + StaticArrays v0.12.4
#   [2913bbd2] + StatsBase v0.33.0
#   [09ab397b] + StructArrays v0.4.4
#   [3783bdb8] + TableTraits v1.0.0
#   [bd369af6] + Tables v1.0.5
#   [83775a58] + Zlib_jll v1.2.11+14
#   [0ac62f75] + libass_jll v0.14.0+2
#   [f638f0a6] + libfdk_aac_jll v0.1.6+2
#   [f27f6e37] + libvorbis_jll v1.3.6+4
#   [1270edf5] + x264_jll v2019.5.25+2
#   [dfaa095f] + x265_jll v3.0.0+1
#   [8bb1440f] + DelimitedFiles
#   [37e2e46d] + LinearAlgebra
#   [2f01184e] + SparseArrays
#   [10745b16] + Statistics
#    Building GR ───→ `C:\Users\Carlos\.julia\packages\GR\8mv9N\deps\build.log`
#    Building Plots → `C:\Users\Carlos\.julia\packages\Plots\LWw1t\deps\build.log`

# %%
using Plots

# %%
# Funções
function f(t,y)
    return y - t^2 + 1.0
end

function euler(t,w,N,h)
    for i in 2:N
        t[i] = t[1] + (i-1)*h
        w[i] = w[i-1] + h*f(t[i-1],w[i-1])
    end
    
    return w
end


# Gráfico
function grafico(t,w)
    p1 = scatter(t,w,c="blue",label="w1")
    plot!(p1,t,w, title="Solução", label="w1")
    xlabel!("t")
    ylabel!("w")
end


function main()
    # Entrada
    N = 10
    a = 0.0
    b = 2.0
    h = (b-a)/N
    
    t    = zeros(N)
    t[1] = a
    
    w    = zeros(N) # Solução aproximada
    w[1] =  0.5     # Condição inicial
    
    # Método de Euler
    w = euler(t,w,N,h)
    
    println("Solução Aproximada: $w")
    
    grafico(t,w)
end


main()
# Out:
# Solução Aproximada: [0.5, 0.8, 1.1520000000000001, 1.5504000000000002, 1.9884800000000002, 2.4581760000000004, 2.9498112000000005, 3.4517734400000006, 3.9501281280000007, 4.428153753600001]
